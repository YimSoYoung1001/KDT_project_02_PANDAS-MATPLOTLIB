# %%
import pandas as pd

# %%
def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()                

    return F

# %%
file1 = '../data_student/학생피해_설문1_가장_두려운_사이버폭력_유형.csv'
file1 = clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사이버 명예훼손  30 non-null     float64
#  1   사이버 언어폭력  30 non-null     float64
#  2   신상정보 유출   30 non-null     float64
#  3   사이버 성폭력   30 non-null     float64
#  4   사이버 스토킹   30 non-null     float64
#  5   사이버 따돋림   30 non-null     float64
#  6   사이버 강요    30 non-null     float64
#  7   사이버 갈취    30 non-null     float64
# dtypes: float64(8)
# memory usage: 3.8 KB

# %%
file1
# Out:
#                       사이버 명예훼손  사이버 언어폭력  신상정보 유출  사이버 성폭력  사이버 스토킹  사이버 따돋림  \
# 특성별(1)      특성별(2)
# 전체          소계            22.9       9.0     34.9      7.8      4.1      8.2
# 성별          남학생           22.2      10.6     30.4      7.6      4.5      6.9
#             여학생           23.6       7.3     39.6      8.0      3.7      9.6
# 학령별         초등학교          17.0      11.4     31.1      7.9      4.5     11.5
#             중학교           25.1       6.9     38.3      6.9      3.7      7.0
#             고등학교          26.6       8.7     35.2      8.7      4.1      6.0
# 학교특성별       남학교           23.6       9.7     35.7      8.5      4.0      4.4
#             여학교           24.3       7.0     43.2      8.6      2.9      6.4
#             남녀공학          26.7       7.4     35.8      7.4      4.1      7.0
# 거주지역별       대도시           22.6       9.6     34.9      8.3      4.1      7.3
#             중소도시          23.1       8.5     35.2      7.4      4.1      8.7
# ...

# %%
file2 = '../data_student/학생피해_설문2_가장_두려운_사이버폭력_유형_123순위.csv'
file2 = clean(file2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사이버 명예훼손  30 non-null     float64
#  1   신상정보 유출   30 non-null     float64
#  2   사이버 언어폭력  30 non-null     float64
#  3   사이버 따돌림   30 non-null     float64
#  4   사이버 성폭력   30 non-null     float64
#  5   사이버 스토킹   30 non-null     float64
#  6   사이버 강요    30 non-null     float64
#  7   사이버 갈취    30 non-null     float64
# dtypes: float64(8)
# memory usage: 3.8 KB

# %%
file2
# Out:
#                       사이버 명예훼손  신상정보 유출  사이버 언어폭력  사이버 따돌림  사이버 성폭력  사이버 스토킹  \
# 특성별(1)      특성별(2)
# 전체          소계            63.1     53.4      43.5     36.5     35.1     32.5
# 성별          남학생           62.1     51.2      43.8     35.3     34.8     33.1
#             여학생           64.1     55.8      43.2     37.8     35.4     31.9
# 학령별         초등학교          57.1     51.2      46.8     39.2     33.9     30.1
#             중학교           67.8     54.2      42.5     35.0     34.9     33.1
#             고등학교          64.4     54.8      41.1     35.3     36.6     34.3
# 학교특성별       남학교           62.9     54.7      38.8     35.7     34.8     36.7
#             여학교           68.7     57.3      39.1     38.7     34.4     30.9
#             남녀공학          62.5     52.8      44.5     36.4     35.2     32.1
# 거주지역별       대도시           63.2     53.0      43.1     35.2     36.7     33.1
#             중소도시          62.2     53.8      43.2     38.2     34.6     31.8
# ...

# %%
file3 = '../data_student/학생피해_설문3_사이버폭력_피해_경험_후_기관에_도움을_청하지_않은_이유.csv'
file3 = clean(file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   별일 아니라고 생각해서          30 non-null     float64
#  1   도움이 될 것 같지 않아서        30 non-null     float64
#  2   상담/신고가 부담스러워서         30 non-null     float64
#  3   주변에 알려지는 것이 창피해서/싫어서  30 non-null     float64
#  4   관련 기관의 존재를 몰라서        30 non-null     float64
#  5   기타                    30 non-null     float64
# dtypes: float64(6)
# memory usage: 3.3 KB

# %%
file3
# Out:
#                       별일 아니라고 생각해서  도움이 될 것 같지 않아서  상담/신고가 부담스러워서  \
# 특성별(1)      특성별(2)
# 전체          소계                66.6             7.9           10.8
# 성별          남학생               68.9             7.2            8.7
#             여학생               63.5             8.8           13.8
# 학령별         초등학교              60.1             4.8           15.6
#             중학교               70.1             9.4            9.2
#             고등학교              70.3             9.7            6.8
# 학교특성별       남학교               75.5             8.2            5.1
#             여학교               66.0            12.2           12.7
#             남녀공학              69.4             9.5            8.4
# 거주지역별       대도시               67.5             6.8           10.8
#             중소도시              65.6             8.1           11.7
#             읍면지역              68.2            10.6            6.9
# 권역별         수도권               67.0             7.6           11.3
# ...

# %%
file4 = '../data_student/학생피해_설문4_사이버폭력_피해_경험_후_무대응_이유.csv'
file4 = clean(file4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   별일 아니라고 생각해서                   30 non-null     float64
#  1   나에게도 잘못이 있다고 생각해서              30 non-null     float64
#  2   대응해도 피해가 멈춰질 것 같지 않아서          30 non-null     float64
#  3   어디에 도움을 요청해야 할지 몰라서            30 non-null     float64
#  4   나에게 피해를 준 상대방이 누구인지 몰라서        30 non-null     float64
#  5   친구들로부터 더 심한 따돌림을 받게 될 것 같아서    30 non-null     float64
#  6   나에게 피해를 준 상대방이 보복(복수) 할 것 같아서  30 non-null     float64
#  7   친구를 잃을 것 같아서                   30 non-null     float64
# dtypes: float64(8)
# memory usage: 3.8 KB

# %%
file4
# Out:
#                       별일 아니라고 생각해서  나에게도 잘못이 있다고 생각해서  대응해도 피해가 멈춰질 것 같지 않아서  \
# 특성별(1)      특성별(2)
# 전체          소계                72.5               19.5                    7.1
# 성별          남학생               74.7               19.5                    5.8
#             여학생               68.0               19.7                   10.0
# 학령별         초등학교              62.3               22.1                    9.5
#             중학교               73.5               21.8                    6.4
#             고등학교              81.7               14.4                    5.5
# 학교특성별       남학교               82.2               15.5                    4.8
#             여학교               74.0               19.1                    7.4
#             남녀공학              76.3               19.1                    6.2
# 거주지역별       대도시               72.3               19.6                    8.7
#             중소도시              73.7               19.5                    6.3
# ...

# %%
file5 = '../data_student/학생피해_설문5_사이버폭력_피해_경험_후_취한_행동.csv'
file5 = clean(file5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       30 non-null     float64
#  1   가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               30 non-null     float64
#  2   가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         30 non-null     float64
#  3   아무런 행동도 하지 않았다                             30 non-null     float64
#  4   해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다  30 non-null     float64
#  5   가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                 30 non-null     float64
# dtypes: float64(6)
# memory usage: 3.3 KB

# %%
file5
# Out:
#                       가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  \
# 특성별(1)      특성별(2)
# 전체          소계                                        40.1
# 성별          남학생                                       35.6
#             여학생                                       46.5
# 학령별         초등학교                                      41.8
#             중학교                                       38.9
#             고등학교                                      39.7
# 학교특성별       남학교                                       33.5
#             여학교                                       49.0
#             남녀공학                                      39.4
# 거주지역별       대도시                                       40.9
#             중소도시                                      39.4
#             읍면지역                                      40.8
# 권역별         수도권                                       40.0
#             충청권                                       37.7
#             호남권                                       43.4
# ...

# %%
file6 = '../data_student/학생피해_설문6_주변인의_사이버폭력_피해_사실_인지_현황_20240119171022.csv'
file6 = clean(file6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   친구들이 알고 있음                  30 non-null     float64
#  1   아무도 모름                      30 non-null     float64
#  2   가족이 알고 있음                   30 non-null     float64
#  3   선생님 또는 학교 폭력 담당 선생님이 알고 있음  30 non-null     float64
#  4   상담 및 신고센터 직원이 알고 있음         30 non-null     float64
#  5   기타                          30 non-null     float64
# dtypes: float64(6)
# memory usage: 3.3 KB

# %%
file6
# Out:
#                       친구들이 알고 있음  아무도 모름  가족이 알고 있음  \
# 특성별(1)      특성별(2)
# 전체          소계              39.6    48.7       16.0
# 성별          남학생             35.4    53.6       11.2
#             여학생             45.4    41.9       22.6
# 학령별         초등학교            33.4    46.7       23.9
#             중학교             44.2    46.7       14.2
#             고등학교            41.4    53.9        8.3
# 학교특성별       남학교             42.4    53.6        5.8
#             여학교             48.3    45.0       18.7
#             남녀공학            42.4    49.4       12.3
# 거주지역별       대도시             39.0    49.5       16.5
#             중소도시            39.8    48.4       15.6
#             읍면지역            40.4    47.0       16.4
# 권역별         수도권             38.7    49.2       16.8
#             충청권             39.7    49.4       14.9
#             호남권             39.0    49.5       14.5
#             동북권             41.5    46.2       16.5
#             동남권             41.2    47.9       15.1
# ...
