# %%
import pandas as pd

# %%
def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()                

    return F

# %%
file1 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__1친구를_만나거나_사귀기가_힘들었음.csv'
file1 = clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file1
# Out:
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             78.1    14.0   5.9     1.9
# 성별          남학생            81.1    13.2   3.8     1.9
#             여학생            74.1    15.1   8.8     2.0
# 학령별         초등학교           78.5    13.9   5.7     2.0
#             중학교            78.1    14.4   5.7     1.8
#             고등학교           77.8    13.6   6.5     2.0
# 학교특성별       남학교            82.4    13.4   3.1     1.1
#             여학교            76.2    10.7   9.3     3.8
#             남녀공학           77.0    14.8   6.3     1.8
# 거주지역별       대도시            79.3    13.4   5.2     2.2
#             중소도시           77.2    14.9   6.2     1.7
#             읍면지역           78.6    11.9   7.0     2.4
# 권역별         수도권            80.4    12.9   4.8     1.8
#             충청권            71.8    16.7   9.3     2.1
#             호남권            78.3    13.1   7.1     1.5
#             동북권            75.6    16.6   6.6     1.2
#             동남권            77.5    14.1   5.4     2.9
# 인터넷 이용 시간별  1시간 미만         74.2    14.5   7.6     3.6
#             1~2시간 미만       80.7    11.2   4.7     3.4
#             2~3시간 미만       80.0    12.2   6.2     1.7
#             3~5시간 미만       76.8    16.6   5.1     1.4
#             5시간 이상         77.1    14.3   6.9     1.7
# 가정형편별       상위             81.7     9.0   5.8     3.5
#             중위             78.0    14.6   5.8     1.6
#             하위             68.3    14.5  10.5     6.7
# 학업성적별       상위권            82.2    10.7   4.5     2.6
#             중위권            78.1    14.5   5.8     1.6
#             하위권            68.0    17.9  10.7     3.4
# 사이버폭력 예방교육별 경험 있음          78.8    13.8   5.8     1.6
#             경험 없음          72.6    15.9   7.0     4.5

# %%
file2 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__2공부를_하고_싶지_않고_학교에_가기_싫었음.csv'
file2 = clean(file2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file2
# Out:
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             72.0    14.7   8.4     4.8
# 성별          남학생            74.1    15.0   6.2     4.7
#             여학생            69.2    14.2  11.5     5.0
# 학령별         초등학교           67.2    16.6   9.8     6.4
#             중학교            72.7    14.9   7.9     4.5
#             고등학교           77.3    11.9   7.6     3.3
# 학교특성별       남학교            81.9    11.9   4.0     2.2
#             여학교            69.8    12.7  11.3     6.2
#             남녀공학           73.4    14.2   8.2     4.1
# 거주지역별       대도시            74.8    13.1   7.3     4.9
#             중소도시           69.8    16.4   9.3     4.5
#             읍면지역           73.2    12.1   8.3     6.3
# 권역별         수도권            74.5    12.9   7.4     5.2
#             충청권            65.3    19.2  10.1     5.3
#             호남권            69.7    14.5  11.6     4.2
#             동북권            70.1    16.3   9.0     4.6
#             동남권            72.1    15.8   8.1     4.1
# 인터넷 이용 시간별  1시간 미만         67.6    21.3   8.7     2.3
#             1~2시간 미만       76.1    12.9   5.8     5.2
#             2~3시간 미만       72.8    16.3   7.0     3.9
#             3~5시간 미만       71.6    15.4   8.8     4.3
#             5시간 이상         70.2    12.7  10.7     6.4
# 가정형편별       상위             72.5    13.6   7.8     6.2
#             중위             72.2    14.9   8.3     4.6
#             하위             66.1    12.0  14.2     7.6
# 학업성적별       상위권            76.5    10.9   7.1     5.5
#             중위권            72.1    15.3   8.3     4.3
#             하위권            60.3    18.2  13.0     8.5
# 사이버폭력 예방교육별 경험 있음          72.5    14.7   8.5     4.3
#             경험 없음          67.9    14.9   7.8     9.5

# %%
file3 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__3자해_자살을_하고_싶은_생각이_들었음.csv'
file3 = clean(file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file3
# Out:
#                       전혀 그렇지 않다  그렇지 않다  그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             80.9    11.3  6.0     1.8
# 성별          남학생            84.8     9.8  4.0     1.4
#             여학생            75.5    13.4  8.7     2.4
# 학령별         초등학교           79.8     9.8  8.5     1.9
#             중학교            79.6    13.1  5.2     2.0
#             고등학교           84.1    10.8  3.7     1.5
# 학교특성별       남학교            89.0     7.8  2.4     0.8
#             여학교            76.0    11.8  9.4     2.7
#             남녀공학           80.3    13.3  4.4     1.9
# 거주지역별       대도시            82.2    10.2  5.3     2.4
#             중소도시           79.5    12.5  6.6     1.4
#             읍면지역           83.2     9.4  5.4     2.0
# 권역별         수도권            83.1    10.6  4.9     1.4
#             충청권            73.5    14.8  9.3     2.4
#             호남권            80.6    12.0  5.9     1.5
#             동북권            79.9    11.3  6.5     2.4
#             동남권            80.3    10.7  6.7     2.3
# 인터넷 이용 시간별  1시간 미만         77.1     8.9  9.1     4.8
#             1~2시간 미만       84.0     9.4  4.1     2.6
#             2~3시간 미만       82.1    11.4  5.1     1.4
#             3~5시간 미만       81.1    11.8  5.4     1.8
#             5시간 이상         78.4    12.1  8.0     1.4
# 가정형편별       상위             77.7    12.7  7.1     2.5
#             중위             81.3    11.2  5.8     1.6
#             하위             80.8     7.4  7.4     4.4
# 학업성적별       상위권            82.6    10.2  4.5     2.8
#             중위권            81.1    11.5  6.0     1.5
#             하위권            75.3    12.3  9.8     2.6
# 사이버폭력 예방교육별 경험 있음          81.3    11.0  6.0     1.7
#             경험 없음          77.3    14.2  5.7     2.8

# %%
file4 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__4우울·불안하거나_심한_스트레스를_받았음.csv'
clean(file4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             66.2    14.1  14.9     4.7
# 성별          남학생            72.2    13.0  11.4     3.4
#             여학생            57.9    15.7  19.9     6.6
# 학령별         초등학교           61.8    15.3  17.2     5.8
#             중학교            66.8    14.2  15.1     3.9
#             고등학교           71.1    12.6  11.8     4.6
# 학교특성별       남학교            78.7    13.0   6.0     2.3
#             여학교            62.2    11.1  17.9     8.8
#             남녀공학           66.8    14.0  15.2     4.0
# 거주지역별       대도시            67.8    13.1  14.3     4.9
#             중소도시           64.9    15.3  15.1     4.6
#             읍면지역           66.6    12.2  16.4     4.8
# 권역별         수도권            67.9    12.8  14.8     4.5
#             충청권            58.8    18.7  17.5     5.0
#             호남권            64.9    15.7  15.4     3.9
#             동북권            66.9    14.6  14.1     4.3
#             동남권            66.4    13.7  13.9     6.0
# 인터넷 이용 시간별  1시간 미만         67.6    13.4  11.3     7.7
#             1~2시간 미만       70.5    13.9  11.3     4.3
#             2~3시간 미만       67.9    14.9  12.6     4.6
#             3~5시간 미만       66.2    14.8  16.0     3.0
#             5시간 이상         62.2    13.1  18.2     6.5
# 가정형편별       상위             64.0    13.2  15.8     7.1
#             중위             66.6    14.4  14.7     4.3
#             하위             60.9    10.9  19.4     8.8
# 학업성적별       상위권            68.2    12.6  13.8     5.3
#             중위권            66.0    14.6  15.1     4.2
#             하위권            62.4    13.3  16.2     8.0
# 사이버폭력 예방교육별 경험 있음          66.3    14.2  15.0     4.4
#             경험 없음          64.9    13.4  14.4     7.3

# %%
file5 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__5잠을_자지_못하거나_두통_복통_등의_증상이_생겼음.csv'
clean(file5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             78.9    12.4   6.4     2.3
# 성별          남학생            83.7    10.5   4.3     1.5
#             여학생            72.4    15.0   9.3     3.3
# 학령별         초등학교           80.7    11.8   5.3     2.2
#             중학교            76.9    13.1   7.6     2.5
#             고등학교           79.4    12.3   6.2     2.0
# 학교특성별       남학교            84.8     9.7   4.7     0.8
#             여학교            70.3    14.1  11.2     4.4
#             남녀공학           77.2    13.4   7.0     2.4
# 거주지역별       대도시            80.6    11.5   5.5     2.4
#             중소도시           77.9    13.5   6.5     2.0
#             읍면지역           77.9    10.3   9.2     2.6
# 권역별         수도권            81.2    11.2   5.4     2.2
#             충청권            71.5    15.7   9.3     3.6
#             호남권            80.7    12.2   5.5     1.6
#             동북권            76.5    14.8   7.2     1.6
#             동남권            77.9    12.3   7.4     2.4
# 인터넷 이용 시간별  1시간 미만         80.5    12.0   4.7     2.8
#             1~2시간 미만       83.5     9.7   3.9     2.9
#             2~3시간 미만       81.8    12.2   4.7     1.4
#             3~5시간 미만       78.4    13.6   6.8     1.3
#             5시간 이상         74.4    12.9   9.1     3.6
# 가정형편별       상위             81.4    10.6   5.0     2.9
#             중위             78.7    12.5   6.7     2.1
#             하위             76.7    15.2   4.2     4.0
# 학업성적별       상위권            81.2    11.0   4.5     3.2
#             중위권            79.3    12.3   6.5     1.9
#             하위권            69.1    17.0  10.7     3.3
# 사이버폭력 예방교육별 경험 있음          79.6    12.2   6.4     1.8
#             경험 없음          73.3    14.1   6.5     6.1

# %%
file6 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__6가해자에게_복수를_하고_싶었음.csv'
clean(file6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             56.0    15.2  19.0     9.8
# 성별          남학생            58.9    14.3  17.0     9.8
#             여학생            52.1    16.5  21.7     9.7
# 학령별         초등학교           49.5    15.4  22.5    12.5
#             중학교            55.0    17.5  19.4     8.1
#             고등학교           65.8    11.8  13.9     8.4
# 학교특성별       남학교            64.2    14.9  14.4     6.5
#             여학교            59.7    18.0  12.2    10.0
#             남녀공학           58.3    14.7  18.5     8.4
# 거주지역별       대도시            56.7    14.0  19.7     9.7
#             중소도시           54.6    16.6  19.0     9.8
#             읍면지역           60.5    12.8  16.9     9.9
# 권역별         수도권            58.3    14.6  18.6     8.6
#             충청권            50.7    15.7  22.6    11.0
#             호남권            58.7    14.1  18.0     9.1
#             동북권            54.5    16.0  17.9    11.6
#             동남권            52.6    16.9  19.1    11.5
# 인터넷 이용 시간별  1시간 미만         56.7    18.2  17.4     7.7
#             1~2시간 미만       55.7    17.5  18.2     8.6
#             2~3시간 미만       56.7    16.2  19.3     7.8
#             3~5시간 미만       57.4    14.5  18.2     9.9
#             5시간 이상         54.2    13.5  20.1    12.1
# 가정형편별       상위             56.4    13.3  17.4    13.0
#             중위             56.2    15.3  19.2     9.2
#             하위             50.3    18.5  17.6    13.6
# 학업성적별       상위권            57.1    14.4  16.5    12.0
#             중위권            56.2    15.3  19.9     8.7
#             하위권            52.0    16.5  16.9    14.6
# 사이버폭력 예방교육별 경험 있음          56.2    15.2  19.0     9.7
#             경험 없음          54.7    15.7  19.2    10.3

# %%
file7 = '../data_student/학생피해_사이버폭력_피해_경험_후_심리상태__7별다른_생각이_들지_않았음.csv'
file7 = clean(file7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전혀 그렇지 않다  30 non-null     float64
#  1   그렇지 않다     30 non-null     float64
#  2   그렇다        30 non-null     float64
#  3   매우 그렇다     30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file7
# Out:
#                       전혀 그렇지 않다  그렇지 않다   그렇다  매우 그렇다
# 특성별(1)      특성별(2)
# 전체          소계             26.9    13.9  27.5    31.7
# 성별          남학생            28.1    12.4  24.8    34.8
#             여학생            25.3    16.0  31.4    27.3
# 학령별         초등학교           28.1    15.2  27.9    28.7
#             중학교            27.3    14.2  28.9    29.6
#             고등학교           24.6    11.9  25.2    38.3
# 학교특성별       남학교            28.4     9.7  26.5    35.4
#             여학교            22.8    15.4  31.1    30.7
#             남녀공학           26.1    13.8  27.0    33.1
# 거주지역별       대도시            27.8    13.1  28.9    30.2
#             중소도시           26.5    14.8  26.5    32.2
#             읍면지역           25.9    12.5  27.9    33.7
# 권역별         수도권            26.5    12.8  26.9    33.9
#             충청권            26.4    17.0  29.6    27.0
#             호남권            24.6    14.9  29.3    31.1
#             동북권            26.9    14.8  28.1    30.2
#             동남권            29.8    13.8  26.7    29.7
# 인터넷 이용 시간별  1시간 미만         38.9     7.4  26.9    26.7
#             1~2시간 미만       30.2    12.9  27.7    29.2
#             2~3시간 미만       28.0    15.4  28.2    28.4
#             3~5시간 미만       23.8    14.0  28.8    33.4
#             5시간 이상         25.8    14.0  25.6    34.6
# 가정형편별       상위             32.0    17.1  22.5    28.4
#             중위             25.9    13.6  28.4    32.1
#             하위             36.8    11.8  21.4    30.0
# 학업성적별       상위권            29.9    13.5  23.7    32.9
#             중위권            26.2    13.8  28.9    31.0
#             하위권            25.6    16.0  23.9    34.6
# 사이버폭력 예방교육별 경험 있음          26.4    13.6  28.2    31.9
#             경험 없음          31.3    16.9  22.1    29.7
