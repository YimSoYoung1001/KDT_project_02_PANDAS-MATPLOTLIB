# %%
import pandas as pd

# %%
def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()                

    return F

# %%
file1 = '../data_student/학생피해_사이버폭력_용인태도__1사이버_언어폭력.csv'
file1 = clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file1
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.4         2.8    38.8       55.9
# 성별          남학생                 3.2         4.0    42.7       50.1
#             여학생                 1.6         1.6    34.7       62.1
# 학령별         초등학교                2.9         3.4    32.0       61.6
#             중학교                 2.2         2.7    45.3       49.7
#             고등학교                2.2         2.3    39.1       56.4
# 학교특성별       남학교                 4.0         4.5    44.9       46.5
#             여학교                 1.3         1.1    31.6       66.1
#             남녀공학                1.9         2.3    43.6       52.1
# 거주지역별       대도시                 2.5         2.5    37.4       57.6
#             중소도시                2.5         3.2    38.7       55.6
#             읍면지역                2.2         2.2    43.7       51.9
# 권역별         수도권                 2.2         2.4    38.4       56.9
# ...

# %%
file2 = '../data_student/학생피해_사이버폭력_용인태도__2사이버_명예훼손.csv'
file2 = clean(file2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file2
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.4         1.4    23.1       73.0
# 성별          남학생                 3.0         2.1    28.2       66.7
#             여학생                 1.8         0.7    17.8       79.8
# 학령별         초등학교                3.5         1.8    22.4       72.4
#             중학교                 2.0         1.5    24.4       72.1
#             고등학교                1.8         1.0    22.6       74.6
# 학교특성별       남학교                 3.0         2.9    29.8       64.3
#             여학교                 1.1         0.3    15.8       82.8
#             남녀공학                1.8         1.0    23.4       73.8
# 거주지역별       대도시                 2.4         1.1    22.3       74.2
#             중소도시                2.6         1.7    22.9       72.7
#             읍면지역                1.7         1.3    26.5       70.6
# 권역별         수도권                 2.2         1.4    21.2       75.2
# ...

# %%
file3 = '../data_student/학생피해_사이버폭력_용인태도__3사이버_스토킹.csv'
file3 = clean(file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file3
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.9         1.6    23.7       71.8
# 성별          남학생                 3.8         2.3    26.8       67.1
#             여학생                 2.0         0.8    20.3       76.8
# 학령별         초등학교                4.4         1.4    18.7       75.5
#             중학교                 2.3         2.2    26.9       68.6
#             고등학교                2.1         1.1    25.6       71.3
# 학교특성별       남학교                 3.4         2.5    32.4       61.8
#             여학교                 1.1         1.0    20.2       77.7
#             남녀공학                2.1         1.5    25.9       70.4
# 거주지역별       대도시                 2.9         1.3    22.5       73.3
#             중소도시                3.2         1.8    23.9       71.1
#             읍면지역                2.2         1.4    26.7       69.7
# 권역별         수도권                 2.6         1.6    23.1       72.8
# ...

# %%
file4 = '../data_student/학생피해_사이버폭력_용인태도__4사이버_성폭력.csv'
file4 = clean(file4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file4
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.9         0.9    17.4       78.8
# 성별          남학생                 3.7         1.4    21.2       73.7
#             여학생                 2.0         0.4    13.3       84.3
# 학령별         초등학교                4.3         0.9    14.6       80.3
#             중학교                 2.2         1.3    19.3       77.2
#             고등학교                2.1         0.7    18.4       78.9
# 학교특성별       남학교                 3.3         1.9    27.3       67.5
#             여학교                 1.1         0.3    12.9       85.7
#             남녀공학                2.1         0.9    17.9       79.2
# 거주지역별       대도시                 2.8         0.7    16.5       80.0
#             중소도시                3.1         1.2    17.4       78.3
#             읍면지역                2.2         0.6    20.2       77.0
# 권역별         수도권                 2.5         1.0    15.3       81.2
# ...

# %%
file5 = '../data_student/학생피해_사이버폭력_용인태도__5신상정보유출.csv'
file5 = clean(file5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file5
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.9         1.0    15.9       80.2
# 성별          남학생                 3.6         1.6    20.0       74.7
#             여학생                 2.1         0.4    11.6       85.9
# 학령별         초등학교                4.3         0.9    11.9       82.8
#             중학교                 2.3         1.4    17.7       78.6
#             고등학교                2.0         0.8    18.2       79.0
# 학교특성별       남학교                 3.3         2.0    23.9       70.7
#             여학교                 1.1         0.2    12.1       86.6
#             남녀공학                2.0         1.0    17.6       79.3
# 거주지역별       대도시                 2.8         0.8    15.3       81.1
#             중소도시                3.1         1.3    16.1       79.5
#             읍면지역                2.2         0.6    17.6       79.5
# 권역별         수도권                 2.6         0.9    14.4       82.0
# ...

# %%
file6 = '../data_student/학생피해_사이버폭력_용인태도__6사이버_따돌림.csv'
file6 = clean(file6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file6
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.9         1.2    20.5       75.4
# 성별          남학생                 3.7         1.9    24.0       70.4
#             여학생                 2.1         0.4    16.7       80.8
# 학령별         초등학교                4.4         1.0    17.5       77.1
#             중학교                 2.3         1.4    23.0       73.3
#             고등학교                2.0         1.1    21.0       75.8
# 학교특성별       남학교                 3.2         2.4    28.9       65.5
#             여학교                 1.2         0.2    14.8       83.7
#             남녀공학                2.1         1.2    21.7       75.0
# 거주지역별       대도시                 2.9         0.8    19.3       77.1
#             중소도시                3.1         1.7    21.0       74.2
#             읍면지역                2.1         0.8    22.4       74.7
# 권역별         수도권                 2.6         1.2    19.1       77.1
# ...

# %%
#file7 = '../data_student/
#file7 = clean(file7)

# %%
file8 = '../data_student/학생피해_사이버폭력_용인태도__8사이버_강요.csv'
file8 = clean(file8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  30 non-null     float64
#  1   문제가 되지 않는다     30 non-null     float64
#  2   문제가 된다         30 non-null     float64
#  3   매우 문제가 된다      30 non-null     float64
# dtypes: float64(4)
# memory usage: 2.9 KB

# %%
file8
# Out:
#                       전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)      특성별(2)
# 전체          소계                  2.8         1.2    22.0       74.0
# 성별          남학생                 3.5         1.7    26.3       68.5
#             여학생                 1.9         0.7    17.4       80.0
# 학령별         초등학교                4.1         1.5    19.8       74.6
#             중학교                 2.2         1.4    24.5       71.9
#             고등학교                1.9         0.7    21.6       75.7
# 학교특성별       남학교                 3.2         2.1    29.1       65.5
#             여학교                 1.2         0.5    15.3       83.0
#             남녀공학                2.0         0.9    23.1       74.1
# 거주지역별       대도시                 2.8         0.9    20.7       75.5
#             중소도시                2.9         1.5    22.3       73.3
#             읍면지역                1.9         1.0    25.1       72.0
# 권역별         수도권                 2.4         1.2    20.8       75.7
# ...
