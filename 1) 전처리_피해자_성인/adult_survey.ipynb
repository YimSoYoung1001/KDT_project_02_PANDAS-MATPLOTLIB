# %%
import pandas as pd

# %%
# adult_mental 파일에서 함수만 복붙해옴

def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()                

    return F

# %%
file1 = '../data_adult/성인피해_설문1_가장_두려운_사이버폭력_유형.csv'
clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   사이버언어폭력  52 non-null     float64
#  1   사이버명예훼손  52 non-null     float64
#  2   사이버스토킹   52 non-null     float64
#  3   신상정보유출   52 non-null     float64
#  4   사이버성폭력   52 non-null     float64
#  5   사이버따돌림   52 non-null     float64
#  6   사이버갈취    52 non-null     float64
#  7   사이버강요    52 non-null     float64
# dtypes: float64(8)
# memory usage: 6.7 KB
#                          사이버언어폭력  사이버명예훼손  사이버스토킹  신상정보유출  사이버성폭력  사이버따돌림  \
# 특성별(1)     특성별(2)
# 전체         소계                9.1     21.5    13.1    22.4    19.9     7.0
# 성별         남성                9.0     20.6    13.4    23.1    19.3     6.7
#            여성                9.2     22.4    12.9    21.8    20.5     7.4
# 연령별        19~29세            8.1     19.6    12.8    25.3    19.4     6.7
# ...

# %%
file2 = '../data_adult/성인피해_설문2_가장_두려운_사이버폭력_유형_123순위.csv'
clean(file2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   사이버명예훼손  52 non-null     float64
#  1   사이버언어폭력  52 non-null     float64
#  2   사이버성폭력   52 non-null     float64
#  3   사이버스토킹   52 non-null     float64
#  4   신상정보유출   52 non-null     float64
#  5   사이버따돌림   52 non-null     float64
#  6   사이버갈취    52 non-null     float64
#  7   사이버강요    52 non-null     float64
# dtypes: float64(8)
# memory usage: 6.7 KB
#                          사이버명예훼손  사이버언어폭력  사이버성폭력  사이버스토킹  신상정보유출  사이버따돌림  \
# 특성별(1)     특성별(2)
# 전체         소계               56.0     50.3    49.6    47.4    42.5    23.0
# 성별         남성               54.8     50.9    49.2    46.6    42.4    24.0
#            여성               57.3     49.7    50.1    48.3    42.5    22.0
# 연령별        20~29세           54.9     47.9    53.7    46.1    42.8    24.1
# ...

# %%
file2
# Out:
# '../data_adult/성인피해_설문2_가장_두려운_사이버폭력_유형_123순위.csv'

# %%
file3 = '../data_adult/성인피해_설문3_사이버폭력_피해_경험_후_기관에_도움을_청하지_않은_이유.csv'
clean(file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   상담/신고가 부담스러워서         52 non-null     float64
#  1   별일 아니라고 생각해서          52 non-null     float64
#  2   도움이 될 것 같지 않아서        52 non-null     float64
#  3   관련 기관의 존재를 몰라서        52 non-null     float64
#  4   주변에 알려지는것이 창피해서/ 싫어서  52 non-null     float64
#  5   기타                    52 non-null     float64
# dtypes: float64(6)
# memory usage: 5.9 KB
#                          상담/신고가 부담스러워서  별일 아니라고 생각해서  도움이 될 것 같지 않아서  \
# 특성별(1)     특성별(2)
# 전체         소계                      6.7          41.1            26.4
# 성별         남성                      8.1          46.1            24.1
#            여성                      4.8          34.7            29.5
# 연령별        19~29세                  7.1          40.5            30.1
# ...

# %%
file4 = '../data_adult/성인피해_설문4_사이버폭력_피해_경험_후_무대응_이유.csv'
clean(file4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   별일 아니라고 생각해서                 52 non-null     float64
#  1   나에게도 잘못이 있다고 생각해서            52 non-null     float64
#  2   어디에 도움을 요청해야 할지 몰라서          52 non-null     float64
#  3   가해자가 보복(복수)할 것 같아서           52 non-null     float64
#  4   가해자가 누구인지 몰라서                52 non-null     float64
#  5   대응해도 피해가 멈춰질 것 같지 않아서        52 non-null     float64
#  6   친구를 잃을 것 같아서                 52 non-null     float64
#  7   친구들로부터 더 심한 따돌림을 받게 될 것 같아서  52 non-null     float64
# dtypes: float64(8)
# memory usage: 6.7 KB
#                          별일 아니라고 생각해서  나에게도 잘못이 있다고 생각해서  어디에 도움을 요청해야 할지 몰라서  \
# 특성별(1)     특성별(2)
# 전체         소계                    53.8                5.4                 17.6
# ...

# %%
file5 = '../data_adult/성인피해_설문5_사이버폭력_피해_경험_후_취한_행동.csv'
clean(file5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  52 non-null     float64
#  1   아무런 행동도 하지 않았다                       52 non-null     float64
#  2   가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         52 non-null     float64
#  3   가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다    52 non-null     float64
#  4   해당 웹사이트나 상담센터 또는 경찰에 신고했다            52 non-null     float64
#  5   가해자에게 보복하거나 다른 사람을 대신 괴롭혔다           52 non-null     float64
# dtypes: float64(6)
# memory usage: 5.9 KB
#                          가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  아무런 행동도 하지 않았다  \
# 특성별(1)     특성별(2)
# 전체         소계                                           41.3            39.5
# 성별         남성                                           36.2            40.4
# ...

# %%
file6 = '../data_adult/성인피해_설문6_주변인의_사이버폭력_피해_사실_인지_현황.csv'
clean(file6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   내 친구들이 알고 있다            52 non-null     float64
#  1   아무도 모른다                 52 non-null     float64
#  2   동료가 알고 있다               52 non-null     float64
#  3   부모 또는 형제자매 등 가족이 알고 있다  52 non-null     float64
#  4   상담 및 신고센터직원이 알고 있다      52 non-null     float64
#  5   기타                      52 non-null     float64
# dtypes: float64(6)
# memory usage: 5.9 KB
#                          내 친구들이 알고 있다  아무도 모른다  동료가 알고 있다  \
# 특성별(1)     특성별(2)
# 전체         소계                    37.4     55.2        6.7
# 성별         남성                    38.0     55.3        7.0
#            여성                    36.6     55.2        6.2
# 연령별        19~29세                44.3     51.3        6.3
# ...

# %%
file7 = '../data_adult/성인피해_설문7_사이버폭력_가해를_하는_주변인_존재_현황.csv'
clean(file7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   없음      52 non-null     float64
#  1   1~3명    52 non-null     float64
#  2   4~6명    52 non-null     float64
#  3   7명 이상   52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB
#                             없음  1~3명  4~6명  7명 이상
# 특성별(1)     특성별(2)
# 전체         소계             98.3   1.6   0.1    0.1
# 성별         남성             97.6   2.1   0.1    0.1
#            여성             99.0   1.0   0.1    0.0
# 연령별        19~29세         96.7   2.9   0.2    0.2
#            30~39세         97.8   2.0   0.1    0.1
#            40~49세         98.2   1.7   0.1    0.0
#            50~59세         99.2   0.8   0.0    0.1
#            60~69세         99.3   0.6   0.1    0.0
# 학력별        초졸이하           98.3   1.7   0.0    0.0
# ...
