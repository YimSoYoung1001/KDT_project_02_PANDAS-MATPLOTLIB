# %%
import pandas as pd

# %%
# adult_mental 파일에서 함수만 복붙해옴

def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()                

    return F

# %%
file1 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__1사이버_언어폭력.csv'
file1 = clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file1
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.5         3.9    43.9       51.7
# 성별         남성                      0.3         4.3    46.7       48.7
#            여성                      0.6         3.4    41.1       54.9
# 연령별        19~29세                  0.6         4.8    43.7       50.9
#            30~39세                  0.4         3.9    45.4       50.3
#            40~49세                  0.3         4.0    43.8       51.9
#            50~59세                  0.5         2.8    43.4       53.2
#            60~69세                  0.7         4.2    43.5       51.7
# 학력별        초졸이하                    0.0         0.0    36.0       64.0
#            중졸                      0.9         1.4    34.1       63.6
#            고졸                      0.4         3.9    43.7       52.0
#            대졸이상                    0.5         4.2    45.1       50.1
# ...

# %%
file2 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__2사이버_명예훼손.csv'
file2 = clean(file2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file2
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.1         0.9    37.0       62.0
# 성별         남성                      0.1         0.9    39.2       59.8
#            여성                      0.0         0.9    34.7       64.4
# 연령별        19~29세                  0.0         0.8    36.4       62.8
#            30~39세                  0.1         1.3    37.2       61.5
#            40~49세                  0.1         1.0    35.6       63.3
#            50~59세                  0.1         0.8    36.8       62.4
#            60~69세                  0.2         0.6    39.1       60.1
# 학력별        초졸이하                    0.0         0.0    32.8       67.2
#            중졸                      0.5         0.3    33.4       65.8
#            고졸                      0.0         0.8    36.4       62.8
#            대졸이상                    0.1         1.0    37.9       60.9
# ...

# %%
file3 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__3사이버_스토킹.csv'
file3 = clean(file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file3
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.2    35.2       64.6
# 성별         남성                      0.0         0.2    37.1       62.7
#            여성                      0.0         0.3    33.2       66.6
# 연령별        19~29세                  0.0         0.2    33.7       66.1
#            30~39세                  0.0         0.3    35.5       64.2
#            40~49세                  0.0         0.1    35.8       64.1
#            50~59세                  0.0         0.3    35.1       64.7
#            60~69세                  0.0         0.2    35.8       63.9
# 학력별        초졸이하                    0.0         0.0    33.1       66.9
#            중졸                      0.0         0.0    29.7       70.3
#            고졸                      0.0         0.3    34.6       65.1
#            대졸이상                    0.0         0.2    36.2       63.6
# ...

# %%
file4 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__4사이버_성폭력.csv'
file4 = clean(file4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file4
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.1    27.7       72.2
# 성별         남성                      0.0         0.1    29.7       70.2
#            여성                      0.0         0.0    25.7       74.3
# 연령별        19~29세                  0.0         0.0    27.4       72.6
#            30~39세                  0.0         0.0    28.1       71.9
#            40~49세                  0.0         0.1    29.1       70.8
#            50~59세                  0.0         0.1    27.1       72.8
#            60~69세                  0.0         0.1    27.0       72.9
# 학력별        초졸이하                    0.0         0.0    18.0       82.0
#            중졸                      0.0         0.0    22.8       77.2
#            고졸                      0.0         0.1    27.0       72.9
#            대졸이상                    0.0         0.0    29.0       71.0
# ...

# %%
file5 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__5신상정보유출.csv'
file5 = clean(file5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file5
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.0    21.8       78.2
# 성별         남성                      0.0         0.0    23.5       76.5
#            여성                      0.0         0.0    20.1       79.8
# 연령별        19~29세                  0.0         0.0    21.4       78.6
#            30~39세                  0.0         0.0    23.8       76.2
#            40~49세                  0.0         0.0    20.9       79.1
#            50~59세                  0.0         0.1    20.9       79.0
#            60~69세                  0.0         0.0    22.5       77.5
# 학력별        초졸이하                    0.0         0.0    18.0       82.0
#            중졸                      0.0         0.0    19.5       80.5
#            고졸                      0.0         0.0    22.1       77.9
#            대졸이상                    0.0         0.0    21.9       78.1
# ...

# %%
file6 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__6사이버_따돌림.csv'
file6 = clean(file6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file6
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.0    26.3       73.7
# 성별         남성                      0.0         0.0    28.4       71.6
#            여성                      0.0         0.0    24.2       75.8
# 연령별        19~29세                  0.0         0.0    26.3       73.7
#            30~39세                  0.0         0.0    27.6       72.4
#            40~49세                  0.0         0.0    26.7       73.3
#            50~59세                  0.0         0.1    25.3       74.6
#            60~69세                  0.0         0.0    26.0       74.0
# 학력별        초졸이하                    0.0         0.0    16.6       83.4
#            중졸                      0.0         0.0    21.0       79.0
#            고졸                      0.0         0.0    26.1       73.8
#            대졸이상                    0.0         0.0    27.2       72.8
# ...

# %%
file7 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__7사이버_갈취.csv'
file7 = clean(file7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file7
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.0    24.6       75.4
# 성별         남성                      0.0         0.0    26.5       73.5
#            여성                      0.0         0.0    22.6       77.4
# 연령별        19~29세                  0.0         0.0    24.3       75.7
#            30~39세                  0.0         0.0    26.5       73.5
#            40~49세                  0.0         0.0    23.6       76.4
#            50~59세                  0.0         0.0    23.5       76.5
#            60~69세                  0.0         0.0    25.3       74.7
# 학력별        초졸이하                    0.0         0.0    18.4       81.6
#            중졸                      0.0         0.0    18.8       81.2
#            고졸                      0.0         0.0    24.9       75.1
#            대졸이상                    0.0         0.0    24.9       75.1
# ...

# %%
file8 = '../data_adult/성인피해_사이버폭력_유형별_용인태도__8사이버_강요.csv'
file8 = clean(file8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   전혀 문제가 되지 않는다  52 non-null     float64
#  1   문제가 되지 않는다     52 non-null     float64
#  2   문제가 된다         52 non-null     float64
#  3   매우 문제가 된다      52 non-null     float64
# dtypes: float64(4)
# memory usage: 5.1 KB

# %%
file8
# Out:
#                          전혀 문제가 되지 않는다  문제가 되지 않는다  문제가 된다  매우 문제가 된다
# 특성별(1)     특성별(2)
# 전체         소계                      0.0         0.0    26.1       73.9
# 성별         남성                      0.0         0.0    28.1       71.9
#            여성                      0.0         0.0    24.0       76.0
# 연령별        19~29세                  0.0         0.0    26.6       73.4
#            30~39세                  0.0         0.0    28.8       71.2
#            40~49세                  0.0         0.0    26.1       73.9
#            50~59세                  0.0         0.0    24.6       75.4
#            60~69세                  0.0         0.0    25.0       75.0
# 학력별        초졸이하                    0.0         0.0    15.4       84.6
#            중졸                      0.0         0.0    18.1       81.9
#            고졸                      0.0         0.0    26.5       73.5
#            대졸이상                    0.0         0.0    26.7       73.3
# ...
