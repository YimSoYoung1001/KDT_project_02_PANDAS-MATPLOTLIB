# %%
import pandas as pd

def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()

    # 들어온 파라미터의 원본을 최종적으로 저장
    file = F

    return file



# --------------------------------------------------------------------------
# 함수 이름 : select
# 매개 변수 : F
# 함수 기능 : 데이터 프레임에서 해당 인덱스 열을 뽑아줌 (DataFrame 형식)
# --------------------------------------------------------------------------
def select(F, indexC):
        result = F.xs(indexC, level = 0)
        return result



# --------------------------------------------------------------------------
# 함수 이름 : ana
# 매개 변수 : name
# 함수 기능 : 각 프레임을 보여주고 describe한 결과를 보여줌
# --------------------------------------------------------------------------
def ana(name):
    print(name)
    print()
    print(name.T.describe())

# %%
file = '../data_student/학생피해_설문5_사이버폭력_피해_경험_후_취한_행동.csv'
file = clean(file)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('전체', '소계') to ('사이버폭력 예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       30 non-null     float64
#  1   가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               30 non-null     float64
#  2   가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         30 non-null     float64
#  3   아무런 행동도 하지 않았다                             30 non-null     float64
#  4   해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다  30 non-null     float64
#  5   가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                 30 non-null     float64
# dtypes: float64(6)
# memory usage: 3.3 KB

# %%
file
# Out:
#                       가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  \
# 특성별(1)      특성별(2)
# 전체          소계                                        40.1
# 성별          남학생                                       35.6
#             여학생                                       46.5
# 학령별         초등학교                                      41.8
#             중학교                                       38.9
#             고등학교                                      39.7
# 학교특성별       남학교                                       33.5
#             여학교                                       49.0
#             남녀공학                                      39.4
# 거주지역별       대도시                                       40.9
#             중소도시                                      39.4
#             읍면지역                                      40.8
# 권역별         수도권                                       40.0
#             충청권                                       37.7
#             호남권                                       43.4
#             동북권                                       41.6
#             동남권                                       39.1
# 인터넷 이용 시간별  1시간 미만                                    38.2
#             1~2시간 미만                                  39.5
#             2~3시간 미만                                  41.7
#             3~5시간 미만                                  39.9
#             5시간 이상                                    39.6
# 가정형편별       상위                                        38.7
#             중위                                        40.3
#             하위                                        40.7
# 학업성적별       상위권                                       37.9
#             중위권                                       41.5
#             하위권                                       32.3
# 사이버폭력 예방교육별 경험 있음                                     41.2
#             경험 없음                                     30.4
#
#                       가해자에게 직접 삭제하도록 하거나 사과를 요구하였다  \
# 특성별(1)      특성별(2)
# 전체          소계                                26.5
# 성별          남학생                               21.6
#             여학생                               33.2
# 학령별         초등학교                              29.8
#             중학교                               28.4
#             고등학교                              19.4
# 학교특성별       남학교                               17.9
#             여학교                               34.1
#             남녀공학                              25.1
# 거주지역별       대도시                               27.1
#             중소도시                              26.1
#             읍면지역                              26.3
# 권역별         수도권                               26.6
#             충청권                               25.0
#             호남권                               25.8
#             동북권                               26.6
#             동남권                               27.5
# 인터넷 이용 시간별  1시간 미만                            30.0
#             1~2시간 미만                          29.5
#             2~3시간 미만                          27.4
#             3~5시간 미만                          24.5
#             5시간 이상                            25.7
# 가정형편별       상위                                33.0
#             중위                                25.7
#             하위                                23.4
# 학업성적별       상위권                               30.3
#             중위권                               26.3
#             하위권                               18.1
# 사이버폭력 예방교육별 경험 있음                             27.4
#             경험 없음                             17.9
#
#                       가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다  아무런 행동도 하지 않았다  \
# 특성별(1)      특성별(2)
# 전체          소계                                      11.5            32.4
# 성별          남학생                                      7.9            38.0
#             여학생                                     16.5            24.6
# 학령별         초등학교                                    14.1            29.5
#             중학교                                     12.6            30.8
#             고등학교                                     6.8            38.2
# 학교특성별       남학교                                      6.0            40.2
#             여학교                                     12.4            29.0
#             남녀공학                                    10.9            33.0
# 거주지역별       대도시                                     11.0            32.4
#             중소도시                                    11.2            32.6
#             읍면지역                                    14.9            31.4
# 권역별         수도권                                     12.1            32.0
#             충청권                                     12.5            34.4
#             호남권                                      9.2            32.5
#             동북권                                     12.0            32.4
#             동남권                                     10.3            31.9
# 인터넷 이용 시간별  1시간 미만                                  20.1            31.3
#             1~2시간 미만                                15.7            29.0
#             2~3시간 미만                                 9.5            30.7
#             3~5시간 미만                                 9.0            34.1
#             5시간 이상                                  12.6            33.9
# 가정형편별       상위                                      18.8            25.7
#             중위                                      10.6            33.2
#             하위                                      12.9            33.5
# 학업성적별       상위권                                     13.4            30.1
#             중위권                                     11.1            32.1
#             하위권                                     10.7            40.8
# 사이버폭력 예방교육별 경험 있음                                   11.5            31.0
#             경험 없음                                   11.4            44.6
#
#                       해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다  \
# 특성별(1)      특성별(2)
# 전체          소계                                              4.4
# 성별          남학생                                             5.1
#             여학생                                             3.5
# 학령별         초등학교                                            3.9
#             중학교                                             5.2
#             고등학교                                            4.1
# 학교특성별       남학교                                             4.4
#             여학교                                             4.4
#             남녀공학                                            4.8
# 거주지역별       대도시                                             4.2
#             중소도시                                            4.7
#             읍면지역                                            4.0
# 권역별         수도권                                             3.8
#             충청권                                             5.7
#             호남권                                             5.2
#             동북권                                             3.4
#             동남권                                             5.6
# 인터넷 이용 시간별  1시간 미만                                          6.6
#             1~2시간 미만                                        3.5
#             2~3시간 미만                                        4.9
#             3~5시간 미만                                        5.0
#             5시간 이상                                          3.6
# 가정형편별       상위                                              4.6
#             중위                                              4.3
#             하위                                              9.0
# 학업성적별       상위권                                             4.7
#             중위권                                             4.5
#             하위권                                             3.2
# 사이버폭력 예방교육별 경험 있음                                           4.4
#             경험 없음                                           4.4
#
#                       가해자에게 보복하거나 다른 사람을 대신 괴롭혔다
# 특성별(1)      특성별(2)
# 전체          소계                               4.0
# 성별          남학생                              6.4
#             여학생                              0.7
# 학령별         초등학교                             2.2
#             중학교                              4.8
#             고등학교                             5.3
# 학교특성별       남학교                             10.6
#             여학교                              0.5
#             남녀공학                             4.2
# 거주지역별       대도시                              4.7
#             중소도시                             3.7
#             읍면지역                             3.3
# 권역별         수도권                              3.6
#             충청권                              4.8
#             호남권                              4.0
#             동북권                              5.8
#             동남권                              3.4
# 인터넷 이용 시간별  1시간 미만                           5.6
#             1~2시간 미만                         2.1
#             2~3시간 미만                         2.5
#             3~5시간 미만                         5.5
#             5시간 이상                           4.6
# 가정형편별       상위                               4.5
#             중위                               3.9
#             하위                               4.9
# 학업성적별       상위권                              4.7
#             중위권                              3.6
#             하위권                              6.1
# 사이버폭력 예방교육별 경험 있음                            3.8
#             경험 없음                            5.7

# %%
# 필요한 데이터프레임만 선택하여 분리함
#성별, 학령별, 학교특성별, 거주지역별, 인터넷 이용 시간별, 가정형편별, 학업성적별, 사이버폭력 예방교육별

gender = select(file, '성별')
school = select(file, '학령별')
schooltype = select(file, '학교특성별')
area = select(file, '거주지역별')
hour = select(file, '인터넷 이용 시간별')
family = select(file, '가정형편별')
score = select(file, '학업성적별')
edu = select(file, '사이버폭력 예방교육별')

# %%
gender = gender.T
gender
# 남학셍 - 무대응
# 여학생 - 가해자를 차단하거나~
# Out:
# 특성별(2)                                      남학생   여학생
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       35.6  46.5
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               21.6  33.2
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다          7.9  16.5
# 아무런 행동도 하지 않았다                             38.0  24.6
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   5.1   3.5
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                  6.4   0.7

# %%
school = school.T
school
# 초등학교 - 가해자를 차단하거나~
# 중학교 - 가해자를 차단하거나~
# 고등학교 - 가해자를 차단하거나~
# Out:
# 특성별(2)                                     초등학교   중학교  고등학교
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       41.8  38.9  39.7
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               29.8  28.4  19.4
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         14.1  12.6   6.8
# 아무런 행동도 하지 않았다                             29.5  30.8  38.2
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   3.9   5.2   4.1
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                  2.2   4.8   5.3

# %%
schooltype = schooltype.T
schooltype
# 남학교 - 무대응
# 여학교 - 가해자를 차단~
# 남녀공학 - 가해자를 차단~
# Out:
# 특성별(2)                                      남학교   여학교  남녀공학
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       33.5  49.0  39.4
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               17.9  34.1  25.1
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다          6.0  12.4  10.9
# 아무런 행동도 하지 않았다                             40.2  29.0  33.0
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   4.4   4.4   4.8
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                 10.6   0.5   4.2

# %%
area = area.T
area
#대도시, 중소도시, 읍면지역 - 가해자를 차단허가나 ~
# Out:
# 특성별(2)                                      대도시  중소도시  읍면지역
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       40.9  39.4  40.8
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               27.1  26.1  26.3
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         11.0  11.2  14.9
# 아무런 행동도 하지 않았다                             32.4  32.6  31.4
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   4.2   4.7   4.0
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                  4.7   3.7   3.3

# %%
hour = hour.T
hour
# 모두 가해자를 차단하거나 나의 아이디나 이메일을 삭제~
# Out:
# 특성별(2)                                     1시간 미만  1~2시간 미만  2~3시간 미만  \
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다         38.2      39.5      41.7
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다                 30.0      29.5      27.4
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다           20.1      15.7       9.5
# 아무런 행동도 하지 않았다                               31.3      29.0      30.7
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다     6.6       3.5       4.9
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                    5.6       2.1       2.5
#
# 특성별(2)                                     3~5시간 미만  5시간 이상
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다           39.9    39.6
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다                   24.5    25.7
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다              9.0    12.6
# 아무런 행동도 하지 않았다                                 34.1    33.9
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다       5.0     3.6
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                      5.5     4.6

# %%
family = family.T
family
# 모두 가해자를 차단하거나~
# Out:
# 특성별(2)                                       상위    중위    하위
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       38.7  40.3  40.7
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               33.0  25.7  23.4
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         18.8  10.6  12.9
# 아무런 행동도 하지 않았다                             25.7  33.2  33.5
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   4.6   4.3   9.0
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                  4.5   3.9   4.9

# %%
score = score.T
score
# 상위권, 중위권은 가해자를 차단하거나~
# 하위권은 무대응~
# Out:
# 특성별(2)                                      상위권   중위권   하위권
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다       37.9  41.5  32.3
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다               30.3  26.3  18.1
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다         13.4  11.1  10.7
# 아무런 행동도 하지 않았다                             30.1  32.1  40.8
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다   4.7   4.5   3.2
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                  4.7   3.6   6.1

# %%
edu = edu.T
edu

# 경험이 있으면 가해자를 차단~
# 경험이 없으면 무대응~
# Out:
# 특성별(2)                                     경험 있음  경험 없음
# 가해자를 차단 하거나 나의 아이디나 이메일을 삭제 또는 변경하였다        41.2   30.4
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다                27.4   17.9
# 가족 친구 선·후배 선생님등 주변에 알리거나 도움을 요청하였다          11.5   11.4
# 아무런 행동도 하지 않았다                              31.0   44.6
# 해당 웹사이트나 상담센터 또는 경찰(학교폭력 신고센터 117등)에 신고했다    4.4    4.4
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다                   3.8    5.7
