# %%
import pandas as pd

def clean(file):
    # 1열은 필요없으므로 건너뛴 상태로 csv파일 부름
    F = pd.read_csv(file, skiprows = 1)       

    # 형변환
    F['특성별(1)'] = F['특성별(1)'].astype('category')
    F['특성별(2)'] = F['특성별(2)'].astype('category')

    # 멀티인덱스 설정
    F.set_index(['특성별(1)','특성별(2)'], inplace = True)

    # 정보 확인
    F.info()

    # 들어온 파라미터의 원본을 최종적으로 저장
    file = F

    return file



# --------------------------------------------------------------------------
# 함수 이름 : select
# 매개 변수 : F
# 함수 기능 : 데이터 프레임에서 해당 인덱스 열을 뽑아줌 (DataFrame 형식)
# --------------------------------------------------------------------------
def select(F, indexC):
        result = F.xs(indexC, level = 0)
        return result



# --------------------------------------------------------------------------
# 함수 이름 : ana
# 매개 변수 : name
# 함수 기능 : 각 프레임을 보여주고 describe한 결과를 보여줌
# --------------------------------------------------------------------------
def ana(name):
    print(name)
    print()
    print(name.T.describe())

# %%
file1 = '../data_adult/성인피해_설문5_사이버폭력_피해_경험_후_취한_행동.csv'
file1 = clean(file1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52 entries, ('전체', '소계') to ('사이버폭력예방교육별', '경험 없음')
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  52 non-null     float64
#  1   아무런 행동도 하지 않았다                       52 non-null     float64
#  2   가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         52 non-null     float64
#  3   가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다    52 non-null     float64
#  4   해당 웹사이트나 상담센터 또는 경찰에 신고했다            52 non-null     float64
#  5   가해자에게 보복하거나 다른 사람을 대신 괴롭혔다           52 non-null     float64
# dtypes: float64(6)
# memory usage: 5.9 KB

# %%
# 필요한 데이터 프레임만 선택하여 데이터프레임으로 만들었음
gender = select(file1, '성별')
age = select(file1, '연령별')
degree = select(file1, '학력별')
job = select(file1, '직업별')
couple = select(file1, '혼인상태별')
area = select(file1, '거주지역별')
hour = select(file1, '인터넷 이용시간별')
edu = select(file1, '사이버폭력예방교육별')

# %%
gender = gender.T
gender
# 남성 - 무대응
# 여성 - 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다
# Out:
# 특성별(2)                                 남성    여성
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  36.2  48.0
# 아무런 행동도 하지 않았다                       40.4  38.3
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         20.7  12.0
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다     6.6   6.6
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다             5.1   5.0
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다            2.9   1.1

# %%
age = age.T
age
# 20대 - 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다
# 30대 - 무대응
# 40대 - 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다
# 50대 - 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다
# 60대 - 아무런 행동도 하지 않았다
# Out:
# 특성별(2)                               19~29세  30~39세  40~49세  50~59세  60~69세
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다    45.7    39.6    39.9    38.6    29.6
# 아무런 행동도 하지 않았다                         38.6    42.0    37.1    33.3    50.5
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다           13.6    17.3    22.7    23.5    11.8
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다       5.6     8.4     6.0     6.3     8.2
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다               5.7     3.3     5.3     6.8     3.9
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다              2.1     3.1     2.2     1.3     0.0

# %%
degree = degree.T
degree
# 초졸이하 - 무대응
# 중졸 - 무대응
# 고졸 - 무대응
# 대졸이상 - 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다
# Out:
# 특성별(2)                                초졸이하    중졸    고졸  대졸이상
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다    0.0  26.0  40.0  42.9
# 아무런 행동도 하지 않았다                       100.0  31.7  40.2  38.9
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다           0.0   0.0  16.5  17.8
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다      0.0  24.6   5.9   6.5
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다              0.0  17.7   3.4   5.7
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다             0.0   0.0   1.7   2.4

# %%
job = job.T
job
# 무대응 - 전문관리, 농어업, 학생, 주부, 무직
# 가해자 차단 ~ - 사무, 서비스판매, 기능노무, 주부
# Out:
# 특성별(2)                               전문관리    사무  서비스판매    농어업  기능노무    학생  \
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  34.6  46.5   40.0    0.0  43.2  37.1
# 아무런 행동도 하지 않았다                       45.5  37.2   36.5  100.0  37.1  39.6
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         11.8  18.9   18.2    0.0  20.0  20.8
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다     4.9   6.5    8.0    0.0  12.6   7.0
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다             4.7   4.0    7.8    0.0   2.6   1.3
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다            2.7   0.6    3.0    0.0   2.2   1.5
#
# 특성별(2)                                 주부  무직/기타
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  46.9   29.3
# 아무런 행동도 하지 않았다                       45.5   47.7
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다          7.8   11.0
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다     3.1    0.0
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다             4.7    8.4
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다            1.5    7.3

# %%
couple = couple.T
couple
#미혼 - 가해자 차단~
#기혼 - 가해자 차단~
#사별/이혼/기타 - 무대응
# Out:
# 특성별(2)                                 미혼    기혼  사별/이혼/기타
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  42.1  41.9      24.8
# 아무런 행동도 하지 않았다                       41.3  35.9      54.9
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         14.6  20.6       8.2
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다     6.3   6.6      11.2
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다             4.4   6.0       4.0
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다            2.5   1.8       0.0

# %%
area = area.T
area
#대도시 - 무대응
#중소도시 - 가해자 차단~
#읍면지역 - 무대응
# Out:
# 특성별(2)                                대도시  중소도시  읍면지역
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다  38.5  46.7  38.3
# 아무런 행동도 하지 않았다                       41.5  33.3  50.3
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다         14.8  23.3   6.5
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다     4.9   9.2   6.6
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다             5.9   4.7   1.6
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다            2.4   2.3   0.0

# %%
hour = hour.T
hour
# 무대응 : 5시간 이상
# 가해자를 차단~ : 1시간, 2시간, 3시간, 5시간 미만
# Out:
# 특성별(2)                               1시간 미만  1~2시간 미만  2~3시간 미만  3~5시간 미만  \
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다    49.7      36.9      43.8      41.5
# 아무런 행동도 하지 않았다                         28.6      36.1      36.7      41.3
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다           21.5      20.0      19.0      15.1
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다      11.6       7.2       7.3       7.8
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다               6.5       3.9       6.1       8.6
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다              2.3       3.3       2.9       2.8
#
# 특성별(2)                               5시간 이상
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다    40.8
# 아무런 행동도 하지 않았다                         46.4
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다           12.7
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다       3.4
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다               2.6
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다              0.0

# %%
edu = edu.T
edu
# 경험 있음 - 가해자 차단~
# 경험 없음 - 무대응
# Out:
# 특성별(2)                               경험 있음  경험 없음
# 가해자를 차단하거나 나의 아이디나 이메일을 삭제 또는 변경하였다   48.1   39.6
# 아무런 행동도 하지 않았다                        32.6   41.3
# 가해자에게 직접 삭제하도록 하거나 사과를 요구하였다          17.8   16.7
# 가족 친구선·후배 동료 등 주변에 알리거나 도움을 요청하였다      6.9    6.5
# 해당 웹사이트나 상담센터 또는 경찰에 신고했다              9.1    4.0
# 가해자에게 보복하거나 다른 사람을 대신 괴롭혔다             3.2    1.8
